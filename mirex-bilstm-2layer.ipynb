# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/mirex-dataset/dataset_info.csv')

# %%
df
# Out:
#      Unnamed: 0                                Title              Artist  \
# 0             0  (Mama) He Treats Your Daughter Mean         Brown, Ruth
# 1             1                     Along Came Jones            Coasters
# 2             2                        Back in Black               AC/DC
# 3             3  Burn Rubber (Why You Wanna Hurt Me)        Gap Band [1]
# 4             4               Cigarettes and Alcohol               Oasis
# ..          ...                                  ...                 ...
# 759         759                 Smokestack Lightning        Howlin' Wolf
# 760         760                            I'm a Man           Yardbirds
# 761         761                       Blow Your Mind              Redman
# 762         762                        Paradise City        Guns N Roses
# 763         763         Deutschland (Has Gotta Die!)  Atari Teenage Riot
#
#                                      Album Audio_Filename  \
# 0               Best of Ruth Brown [Rhino]        001.mp3
# 1          50 Coastin' Classics: Anthology        003.mp3
# 2                            Back in Black        004.mp3
# 3              Billboard Hot R&B Hits 1981        007.mp3
# 4                         Definitely Maybe        008.mp3
# ..                                     ...            ...
# 759  Howlin' Wolf/Moanin' in the Moonlight        899.mp3
# 760       Greatest Hits, Vol. 1: 1964-1966        900.mp3
# 761                       Whut? Thee Album        901.mp3
# 762               Appetite for Destruction        902.mp3
# 763                     Burn, Berlin, Burn        903.mp3
#
#                                                 Lyrics    Category    Cluster
# 0    Mama he treats your daughter mean \nMama he tr...  Boisterous  Cluster 1
# 1    I plopped down in my easy chair and turned on ...  Boisterous  Cluster 1
# 2    Back in black \nI hit the sack \nIt's been too...  Boisterous  Cluster 1
# 3    Woo, I gave you my money, I gave you my time.\...  Boisterous  Cluster 1
# 4    Is it my imagination \nOr have I finally found...  Boisterous  Cluster 1
# ..                                                 ...         ...        ...
# 759  (Chester Burnett a.k.a. Howlin' Wolf)\nAh-oh, ...   Agressive  Cluster 5
# 760  You pretty women,\nStanding in line,\nMake lov...   Agressive  Cluster 5
# 761  AHHHH!! Look out  it's the Funkadelic Funk for...   Agressive  Cluster 5
# 762  [Chorus: x2]\n\nTake me down\nTo the paradise ...       Fiery  Cluster 5
# 763  Deutschland has gotta die! (eins, zwei, drei, ...       Fiery  Cluster 5
#
# [764 rows x 8 columns]

# %%
df['Lyrics'] = df['Lyrics'].map(lambda x: x.replace('\n',' '))
df
# Out:
#      Unnamed: 0                                Title              Artist  \
# 0             0  (Mama) He Treats Your Daughter Mean         Brown, Ruth
# 1             1                     Along Came Jones            Coasters
# 2             2                        Back in Black               AC/DC
# 3             3  Burn Rubber (Why You Wanna Hurt Me)        Gap Band [1]
# 4             4               Cigarettes and Alcohol               Oasis
# ..          ...                                  ...                 ...
# 759         759                 Smokestack Lightning        Howlin' Wolf
# 760         760                            I'm a Man           Yardbirds
# 761         761                       Blow Your Mind              Redman
# 762         762                        Paradise City        Guns N Roses
# 763         763         Deutschland (Has Gotta Die!)  Atari Teenage Riot
#
#                                      Album Audio_Filename  \
# 0               Best of Ruth Brown [Rhino]        001.mp3
# 1          50 Coastin' Classics: Anthology        003.mp3
# 2                            Back in Black        004.mp3
# 3              Billboard Hot R&B Hits 1981        007.mp3
# 4                         Definitely Maybe        008.mp3
# ..                                     ...            ...
# 759  Howlin' Wolf/Moanin' in the Moonlight        899.mp3
# 760       Greatest Hits, Vol. 1: 1964-1966        900.mp3
# 761                       Whut? Thee Album        901.mp3
# 762               Appetite for Destruction        902.mp3
# 763                     Burn, Berlin, Burn        903.mp3
#
#                                                 Lyrics    Category    Cluster
# 0    Mama he treats your daughter mean  Mama he tre...  Boisterous  Cluster 1
# 1    I plopped down in my easy chair and turned on ...  Boisterous  Cluster 1
# 2    Back in black  I hit the sack  It's been too l...  Boisterous  Cluster 1
# 3    Woo, I gave you my money, I gave you my time. ...  Boisterous  Cluster 1
# 4    Is it my imagination  Or have I finally found ...  Boisterous  Cluster 1
# ..                                                 ...         ...        ...
# 759  (Chester Burnett a.k.a. Howlin' Wolf) Ah-oh, s...   Agressive  Cluster 5
# 760  You pretty women, Standing in line, Make love ...   Agressive  Cluster 5
# 761  AHHHH!! Look out  it's the Funkadelic Funk for...   Agressive  Cluster 5
# 762  [Chorus: x2]  Take me down To the paradise cit...       Fiery  Cluster 5
# 763  Deutschland has gotta die! (eins, zwei, drei, ...       Fiery  Cluster 5
#
# [764 rows x 8 columns]

# %%
all_emotions = df['Category'].unique()
print(len(all_emotions))
# Out:
# 24

# %%
idx_to_emotions = dict()
emotions_to_idx = dict()
for i, j in enumerate(all_emotions):
    idx_to_emotions[i] = j
    emotions_to_idx[j] = i

# %%
df['Category'] = df['Category'].map(lambda x: emotions_to_idx[x])

# %%
df['Category']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 759    22
# 760    22
# 761    22
# 762    23
# 763    23
# Name: Category, Length: 764, dtype: int64

# %%
X = df['Lyrics']
y = df['Category']

# %%
clusters = df['Cluster'].unique()
clusters
# Out:
# array(['Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4', 'Cluster 5'],
#       dtype=object)

# %%
cluster_to_idx = dict()
idx_to_cluster = dict()
for i in range(0, len(clusters)):
    cluster_to_idx[clusters[i]] = i
    idx_to_cluster[i] = clusters[i]
cluster_to_idx
# Out:
# {'Cluster 1': 0,
#  'Cluster 2': 1,
#  'Cluster 3': 2,
#  'Cluster 4': 3,
#  'Cluster 5': 4}

# %%
df['Cluster'] = df['Cluster'].map(lambda x: cluster_to_idx[x])

# %%
df
# Out:
#      Unnamed: 0                                Title              Artist  \
# 0             0  (Mama) He Treats Your Daughter Mean         Brown, Ruth
# 1             1                     Along Came Jones            Coasters
# 2             2                        Back in Black               AC/DC
# 3             3  Burn Rubber (Why You Wanna Hurt Me)        Gap Band [1]
# 4             4               Cigarettes and Alcohol               Oasis
# ..          ...                                  ...                 ...
# 759         759                 Smokestack Lightning        Howlin' Wolf
# 760         760                            I'm a Man           Yardbirds
# 761         761                       Blow Your Mind              Redman
# 762         762                        Paradise City        Guns N Roses
# 763         763         Deutschland (Has Gotta Die!)  Atari Teenage Riot
#
#                                      Album Audio_Filename  \
# 0               Best of Ruth Brown [Rhino]        001.mp3
# 1          50 Coastin' Classics: Anthology        003.mp3
# 2                            Back in Black        004.mp3
# 3              Billboard Hot R&B Hits 1981        007.mp3
# 4                         Definitely Maybe        008.mp3
# ..                                     ...            ...
# 759  Howlin' Wolf/Moanin' in the Moonlight        899.mp3
# 760       Greatest Hits, Vol. 1: 1964-1966        900.mp3
# 761                       Whut? Thee Album        901.mp3
# 762               Appetite for Destruction        902.mp3
# 763                     Burn, Berlin, Burn        903.mp3
#
#                                                 Lyrics  Category  Cluster
# 0    Mama he treats your daughter mean  Mama he tre...         0        0
# 1    I plopped down in my easy chair and turned on ...         0        0
# 2    Back in black  I hit the sack  It's been too l...         0        0
# 3    Woo, I gave you my money, I gave you my time. ...         0        0
# 4    Is it my imagination  Or have I finally found ...         0        0
# ..                                                 ...       ...      ...
# 759  (Chester Burnett a.k.a. Howlin' Wolf) Ah-oh, s...        22        4
# 760  You pretty women, Standing in line, Make love ...        22        4
# 761  AHHHH!! Look out  it's the Funkadelic Funk for...        22        4
# 762  [Chorus: x2]  Take me down To the paradise cit...        23        4
# 763  Deutschland has gotta die! (eins, zwei, drei, ...        23        4
#
# [764 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=56)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=56)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, df['Cluster'], test_size=0.3, random_state=56)

X_train1, X_val11, y_train, y_val1 = train_test_split(X_train1, y_train1, test_size=0.25, random_state=56)

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torch.nn.utils.rnn import pad_sequence
from torch.nn.utils.rnn import pack_padded_sequence
from torch.nn.utils.rnn import pad_packed_sequence
from torch.optim.lr_scheduler import StepLR,ReduceLROnPlateau
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
all_words_vocab = dict()
all_words_vocab['pad'] = 0
all_words_vocab['unk'] = 1
count = 2

for i in X_train:
    for j in i.split(' '):
        if j not in all_words_vocab.keys():
            all_words_vocab[j] = count
            count += 1
print(len(all_words_vocab))
# Out:
# 11041

# %%
def textEncoder(sample):
    output = list()
    for i in sample:
        if i in all_words_vocab.keys():
            output.append(all_words_vocab[i])
        else:
            output.append(all_words_vocab['unk'])
    return output

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove.6B.zip

# %%
glove_embeddings_dict = dict()
embedding_dim = 100
with open("/kaggle/input/embedded/glove.6B.100d.txt",encoding="utf8") as lines:
    for line in lines:
        line_split = line.split()
        word = line_split[0]
        vector = np.asarray(line_split[1:], dtype='float32')
        glove_embeddings_dict[word] = vector

# %%
def textEncoder2(sample):
    mask_list = list()
    for i in sample:
        is_uppercase = False
        for j in i:
            if j.isupper():
                is_uppercase = True
                break
        if is_uppercase:
            mask_list.append(1)
        else:
            mask_list.append(0)
    return mask_list

# %%
X_train_mask = X_train.map(textEncoder2)
X_test_mask = X_test.map(textEncoder2)
X_val_mask = X_val.map(textEncoder2)

# %%
X_train = X_train.map(textEncoder)
X_test = X_test.map(textEncoder)
X_val = X_val.map(textEncoder)

# %%
class createDataset2(Dataset):
    def __init__(self, X_train, y_train, mask):
        temp1, temp2, lengths, temp3 = list(), list(), list(), list()
        count = 0
        for x, y, m in zip(X_train,y_train,mask):
            count+=1
            temp1.append(torch.LongTensor(x))
            lengths.append(len(x))
            temp2.append(y)
            temp3.append(torch.Tensor(m))
        
        self.X = pad_sequence(temp1,batch_first=True, padding_value=all_words_vocab['pad'])
        self.X_packed = pack_padded_sequence(self.X, lengths, batch_first=True, enforce_sorted=False)
        self.y = torch.tensor(temp2)#pad_sequence(temp2,batch_first=True,padding_value=25)  
        self.mask = pad_sequence(temp3,batch_first=True, padding_value=0)
        self.lengths = torch.Tensor(lengths).int()
        self.X = self.X.to(device)
        self.y = self.y.to(device)
        self.mask = self.mask.to(device)


    def __getitem__(self, index):
        return self.X[index], self.y[index], self.lengths[index], self.mask[index]

    def __len__(self):
        return len(self.X)

# %%
batch_size = 8
train_data2 = createDataset2(X_train,y_train,X_train_mask)
train_loader2 = torch.utils.data.DataLoader(train_data2,batch_size=batch_size)
validation_data2 = createDataset2(X_val,y_val, X_val_mask)
validation_loader2 = torch.utils.data.DataLoader(validation_data2,batch_size=batch_size)
validation_data2_ = createDataset2(X_val,y_val,X_val_mask)
validation_loader2_ = torch.utils.data.DataLoader(validation_data2_,batch_size=1)
train_data2_ = createDataset2(X_train,y_train,X_train_mask)
train_loader2_ = torch.utils.data.DataLoader(train_data2,batch_size=1)

# %%
train_data21 = createDataset2(X_train,y_train1,X_train_mask)
train_loader21 = torch.utils.data.DataLoader(train_data2,batch_size=batch_size)
validation_data21 = createDataset2(X_val,y_val1, X_val_mask)
validation_loader21 = torch.utils.data.DataLoader(validation_data2,batch_size=batch_size)
validation_data21_ = createDataset2(X_val,y_val1,X_val_mask)
validation_loader21_ = torch.utils.data.DataLoader(validation_data21_,batch_size=1)
train_data21_ = createDataset2(X_train,y_train1,X_train_mask)
train_loader21_ = torch.utils.data.DataLoader(train_data21,batch_size=1)

# %%
class BiLSTMwithGlove(nn.Module):
    def __init__(self, vocab_size, embedding_dim, lstm_hidden_units, output_dim, number_of_labels, embedding_weights):
        super(BiLSTMwithGlove, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.embedding.weight.data.copy_(torch.from_numpy(embedding_weights))
        self.bilstm = nn.LSTM(embedding_dim+1, lstm_hidden_units, bidirectional = True, batch_first = True)
        self.bilstm2 = nn.LSTM(lstm_hidden_units * 2, lstm_hidden_units, bidirectional=True, batch_first=True)
        self.linear = nn.Linear(lstm_hidden_units * 2 , output_dim)
        self.dropout = nn.Dropout(0.33)
        self.relu = nn.ReLU()
        self.linear1 = nn.Linear(output_dim, number_of_labels)

    def forward(self, x, lengths, mask):
        x = self.embedding(x)
        mask = torch.unsqueeze(mask, dim=2)       
        x = torch.cat((x,mask),dim=2)
        x = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        x, _ = self.bilstm(x)
        x, _ = pad_packed_sequence(x, batch_first=True)
        x = self.dropout(x)
        x = pack_padded_sequence(x, lengths, batch_first=True, enforce_sorted=False)
        x, _ = self.bilstm2(x)
        x, _ = pad_packed_sequence(x, batch_first=True)
        x = self.dropout(x)
        x = self.linear(x)
        x = self.relu(x)
        x = self.linear1(x)
        x, _ = torch.max(x, dim=1)
        return x

# %%
vocab_size = len(all_words_vocab)
pretrained_weights = np.zeros((vocab_size, embedding_dim), dtype="float32")
np.random.seed(69)
for word,key in all_words_vocab.items():
    if key == 0:
        pretrained_weights[key] = np.zeros(embedding_dim, dtype='float32')

    if key==1:
        weight = np.random.uniform(-0.01,0.01, embedding_dim)
        pretrained_weights[key] = weight

    else:
        lowercase = word.lower()
        if lowercase in glove_embeddings_dict.keys():
            if word in glove_embeddings_dict.keys():
                weight = glove_embeddings_dict[word]
            else:
                weight = glove_embeddings_dict[lowercase]
            pretrained_weights[key] = weight
        else:
            temp = np.random.uniform(-0.01,0.01, embedding_dim)
            pretrained_weights[key] = temp

# %%
vocab_size = len(all_words_vocab)
embedding_dim = 100
lstm_hidden_units = 250
number_of_labels = 24 
output_dim = 50
vocab_size
# Out:
# 11041

# %%
model2 = BiLSTMwithGlove(vocab_size, embedding_dim, lstm_hidden_units, output_dim, number_of_labels, pretrained_weights)
criterion2 = nn.CrossEntropyLoss()
optimizer2 = torch.optim.SGD(model2.parameters(),lr=0.75)

# %%
model2 = model2.to(device)
criterion2 = criterion2.to(device)

# %%
def run_train2(model2, optimizer2, loader2, criterion2, flag2):
    train_loss_epoch = 0
    train_accuracy_epoch = 0
    train_loss = list()
    correct_predictions = 0
    total_samples = 0
    for data, ground_truth, sentence_length, mask in loader2:
        optimizer2.zero_grad()
        predicted_y = model2(data, sentence_length, mask)
        training_loss = criterion2(predicted_y, ground_truth)
        if flag2:
            training_loss.backward()
            optimizer2.step()
        train_loss_epoch += training_loss.item()
        train_loss.append(train_loss_epoch)
        _, predicted_labels = torch.max(predicted_y, 1)
        correct_predictions += (predicted_labels == ground_truth).sum().item()
        total_samples += ground_truth.size(0)
        accuracy = correct_predictions / total_samples
        train_accuracy_epoch += accuracy
    return train_loss_epoch, train_accuracy_epoch, train_loss

# %%
def get_prediction_list2(model, loader, sentences, all_emotions):
    prediction_list = list()
    ground_truth_list = list()
    
    with torch.no_grad():
        prev = list()
        for ((x, y, length,mask),sentence) in zip(loader, sentences):
            prediction = model(x,length,mask)
            x = x.tolist()
            y = y.tolist()[0]
            prediction = prediction.argmax(-1)
            prediction = prediction.tolist()[0]
            prediction_list.append(prediction)
            ground_truth_list.append(y)

    return prediction_list, ground_truth_list

# %%
from sklearn.metrics import precision_recall_fscore_support

# %%
minimum_training_loss = np.inf
train_loss, validation_loss = list(), list()
prev_f1 = 0

for epoch in range(50):
    model2.train()
    train_loss_epoch, train_accuracy_epoch, train_loss = run_train2(model2, optimizer2, train_loader2, criterion2, True)
    train_accuracy_epoch = train_accuracy_epoch / len(train_loader2)
    train_loss_epoch = train_loss_epoch / len(train_loader2)
    model2.eval()
    validation_loss_epoch, validation_accuracy_epoch, validation_loss = run_train2(model2, optimizer2, validation_loader2, criterion2, False)
    validation_accuracy_epoch = validation_accuracy_epoch / len(validation_loader2)
    validation_loss_epoch = validation_loss_epoch / len(validation_loader2)
    print("Epoch: {:.0f} Training Accuracy: {:.4f} Training Loss: {:.4f} Validation Accuracy: {:.4f} Validation Loss: {:.4f} ".format(epoch,train_accuracy_epoch,train_loss_epoch,validation_accuracy_epoch,validation_loss_epoch))

    prediction_list, ground_truth_list = get_prediction_list2(model2, validation_loader2_,X_val,idx_to_emotions)
#     print(prediction_list, ground_truth_list)
    precision, recall, f1,_ = precision_recall_fscore_support (ground_truth_list, prediction_list, average='weighted',zero_division=0)
    print(precision, recall,  f1)
# Out:
# Epoch: 0 Training Accuracy: 0.2323 Training Loss: 1.8930 Validation Accuracy: 0.0146 Validation Loss: 5.1241
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 1 Training Accuracy: 0.2178 Training Loss: 1.6135 Validation Accuracy: 0.0146 Validation Loss: 5.4490
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 2 Training Accuracy: 0.2138 Training Loss: 1.5861 Validation Accuracy: 0.0146 Validation Loss: 5.6212
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 3 Training Accuracy: 0.2138 Training Loss: 1.5733 Validation Accuracy: 0.0146 Validation Loss: 5.7477
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 4 Training Accuracy: 0.1902 Training Loss: 1.5662 Validation Accuracy: 0.0146 Validation Loss: 5.8572
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 5 Training Accuracy: 0.1891 Training Loss: 1.5590 Validation Accuracy: 0.0146 Validation Loss: 5.9628
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 6 Training Accuracy: 0.1977 Training Loss: 1.5564 Validation Accuracy: 0.0146 Validation Loss: 5.9183
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 7 Training Accuracy: 0.1975 Training Loss: 1.5519 Validation Accuracy: 0.0146 Validation Loss: 6.0333
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 8 Training Accuracy: 0.1975 Training Loss: 1.5490 Validation Accuracy: 0.0146 Validation Loss: 6.1331
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 9 Training Accuracy: 0.1975 Training Loss: 1.5464 Validation Accuracy: 0.0146 Validation Loss: 6.1121
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 10 Training Accuracy: 0.1975 Training Loss: 1.5450 Validation Accuracy: 0.0146 Validation Loss: 6.1616
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 11 Training Accuracy: 0.1966 Training Loss: 1.5432 Validation Accuracy: 0.0146 Validation Loss: 6.1862
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 12 Training Accuracy: 0.1966 Training Loss: 1.5418 Validation Accuracy: 0.0146 Validation Loss: 6.1903
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 13 Training Accuracy: 0.2000 Training Loss: 1.5421 Validation Accuracy: 0.0146 Validation Loss: 6.0625
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 14 Training Accuracy: 0.2000 Training Loss: 1.5401 Validation Accuracy: 0.0146 Validation Loss: 6.2336
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 15 Training Accuracy: 0.2000 Training Loss: 1.5388 Validation Accuracy: 0.0146 Validation Loss: 6.2648
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 16 Training Accuracy: 0.2111 Training Loss: 1.5374 Validation Accuracy: 0.0146 Validation Loss: 6.2595
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 17 Training Accuracy: 0.2166 Training Loss: 1.5367 Validation Accuracy: 0.0146 Validation Loss: 6.2738
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 18 Training Accuracy: 0.2162 Training Loss: 1.5381 Validation Accuracy: 0.0146 Validation Loss: 6.1462
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 19 Training Accuracy: 0.2055 Training Loss: 1.5352 Validation Accuracy: 0.0146 Validation Loss: 6.4387
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 20 Training Accuracy: 0.2005 Training Loss: 1.5378 Validation Accuracy: 0.0146 Validation Loss: 6.0821
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 21 Training Accuracy: 0.2172 Training Loss: 1.5362 Validation Accuracy: 0.0146 Validation Loss: 6.1868
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 22 Training Accuracy: 0.2136 Training Loss: 1.5355 Validation Accuracy: 0.0146 Validation Loss: 6.2286
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 23 Training Accuracy: 0.2166 Training Loss: 1.5344 Validation Accuracy: 0.0146 Validation Loss: 6.4660
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 24 Training Accuracy: 0.2181 Training Loss: 1.5331 Validation Accuracy: 0.0146 Validation Loss: 6.4290
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 25 Training Accuracy: 0.2152 Training Loss: 1.5326 Validation Accuracy: 0.0146 Validation Loss: 6.4981
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 26 Training Accuracy: 0.2171 Training Loss: 1.5369 Validation Accuracy: 0.0146 Validation Loss: 6.2073
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 27 Training Accuracy: 0.2171 Training Loss: 1.5364 Validation Accuracy: 0.0146 Validation Loss: 6.1007
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 28 Training Accuracy: 0.2166 Training Loss: 1.5347 Validation Accuracy: 0.0146 Validation Loss: 6.1154
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 29 Training Accuracy: 0.2166 Training Loss: 1.5339 Validation Accuracy: 0.0146 Validation Loss: 6.1057
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 30 Training Accuracy: 0.2166 Training Loss: 1.5328 Validation Accuracy: 0.0146 Validation Loss: 6.1367
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 31 Training Accuracy: 0.2162 Training Loss: 1.5323 Validation Accuracy: 0.0146 Validation Loss: 6.1739
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 32 Training Accuracy: 0.2299 Training Loss: 1.5313 Validation Accuracy: 0.0146 Validation Loss: 6.2350
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 33 Training Accuracy: 0.2166 Training Loss: 1.5309 Validation Accuracy: 0.0146 Validation Loss: 6.2702
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 34 Training Accuracy: 0.2366 Training Loss: 1.5304 Validation Accuracy: 0.0146 Validation Loss: 6.3544
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 35 Training Accuracy: 0.2156 Training Loss: 1.5316 Validation Accuracy: 0.0146 Validation Loss: 6.3766
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 36 Training Accuracy: 0.2166 Training Loss: 1.5314 Validation Accuracy: 0.0146 Validation Loss: 6.1456
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 37 Training Accuracy: 0.2366 Training Loss: 1.5310 Validation Accuracy: 0.0146 Validation Loss: 6.0837
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 38 Training Accuracy: 0.2387 Training Loss: 1.5304 Validation Accuracy: 0.0146 Validation Loss: 6.0754
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 39 Training Accuracy: 0.2387 Training Loss: 1.5298 Validation Accuracy: 0.0146 Validation Loss: 5.9898
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 40 Training Accuracy: 0.2387 Training Loss: 1.5288 Validation Accuracy: 0.0146 Validation Loss: 6.0602
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 41 Training Accuracy: 0.2387 Training Loss: 1.5281 Validation Accuracy: 0.0146 Validation Loss: 6.1669
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 42 Training Accuracy: 0.2387 Training Loss: 1.5274 Validation Accuracy: 0.0146 Validation Loss: 6.1849
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 43 Training Accuracy: 0.2366 Training Loss: 1.5263 Validation Accuracy: 0.0146 Validation Loss: 6.2295
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 44 Training Accuracy: 0.2387 Training Loss: 1.5258 Validation Accuracy: 0.0146 Validation Loss: 6.3263
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 45 Training Accuracy: 0.2387 Training Loss: 1.5255 Validation Accuracy: 0.0146 Validation Loss: 6.3542
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 46 Training Accuracy: 0.2416 Training Loss: 1.5250 Validation Accuracy: 0.0146 Validation Loss: 6.3314
# 0.0020049008687903764 0.04477611940298507 0.0038379530916844346
# Epoch: 47 Training Accuracy: 0.2416 Training Loss: 1.5246 Validation Accuracy: 0.0146 Validation Loss: 6.3721
# 0.0020199753114128606 0.04477611940298507 0.003865564265005906
# Epoch: 48 Training Accuracy: 0.2416 Training Loss: 1.5237 Validation Accuracy: 0.0146 Validation Loss: 6.4093
# 0.0020199753114128606 0.04477611940298507 0.003865564265005906
# Epoch: 49 Training Accuracy: 0.2416 Training Loss: 1.5234 Validation Accuracy: 0.0146 Validation Loss: 6.4460
# 0.0020199753114128606 0.04477611940298507 0.003865564265005906
